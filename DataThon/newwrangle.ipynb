# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np

# %%
df = pd.read_csv("newtrain.csv")

# %%
df[['purchace_time','n']]=df['pt'].str.split('+', expand=True)

# %%
df.drop('n', inplace=True, axis=1)
df.drop('pt', inplace=True, axis=1)

# %%
df[['departure_time','n']]=df['dt'].str.split('+', expand=True)
df.drop('n', inplace=True, axis=1)
df.drop('dt', inplace=True, axis=1)

# %%
df[['arival_time','n']]=df['at'].str.split('+', expand=True)
df.drop('n', inplace=True, axis=1)
df.drop('at', inplace=True, axis=1)

# %%
df = df.drop("Unnamed: 0",axis=1)

# %%
df=df.rename(columns={"f2": "origin", "f3": "destination","f6": "airline", "f7": "refundable","f8": "baggage_weight", "f9": "baggage_pieces","f10":"flight_number","pd": "purchace_date", "dd": "departure_date","ad":"arival_date"})

# %%
df.to_csv("newtrain1.csv",index=False)

# %%
df = pd.read_csv("newtrain1.csv")

# %%
df.head()
# Out:
#    origin  destination airline  refundable  baggage_weight  baggage_pieces  \
# 0       0            1   gamma           1        0.000000               0
# 1       0            1   gamma           1        0.711111               1
# 2       0            1   gamma           1        0.711111               1
# 3       0            1   gamma           1        0.711111               2
# 4       0            1    beta           0        0.444444               0
#
#   flight_number purchace_date departure_date arival_date    purchace_time  \
# 0           c-2    2020-12-31     2021-01-10  2021-01-10  09:46:17.463002
# 1           c-2    2020-12-31     2021-01-10  2021-01-10  09:46:17.463002
# 2           c-4    2020-12-31     2021-01-10  2021-01-10  09:46:17.463002
# 3           c-4    2020-12-31     2021-01-10  2021-01-10  09:46:17.463002
# 4          b-69    2020-12-31     2021-01-25  2021-01-25  09:46:18.191119
#
#   departure_time arival_time
# 0       05:00:00    07:00:00
# ...

# %%
df = df.replace('gamma',0)
df = df.replace('beta',1)
df = df.replace('alpha',2)
df = df.replace('omega',3)

# %%
df = df.replace('beta',1)

# %%
df = df.replace('alpha',2)

# %%
df = df.replace('omega',3)

# %%
df['origin'] = df['origin'].replace(0,'x')
df['destination'] = df['destination'].replace(1,'y')

# %%
df
# Out:
#          origin destination  airline  refundable  baggage_weight  \
# 0             x           y        0           1        0.000000
# 1             x           y        0           1        0.711111
# 2             x           y        0           1        0.711111
# 3             x           y        0           1        0.711111
# 4             x           y        1           0        0.444444
# ...         ...         ...      ...         ...             ...
# 21776585      x           y        2           1        0.444444
# 21776586      x           y        2           1        0.333333
# 21776587      x           y        3           1        0.444444
# 21776588      x           y        3           1        0.444444
# 21776589      x           y        3           1        0.444444
#
#           baggage_pieces flight_number purchace_date departure_date  \
# 0                      0           c-2    2020-12-31     2021-01-10
# ...

# %%
df2=pd.read_csv("y_train.csv")

# %%
df2 = df2.drop("Unnamed: 0",axis=1)

# %%
df["price"] = df2

# %%
df
# Out:
#           origin  destination  airline  refundable  baggage_weight  \
# 0              0            1        0           1        0.000000
# 1              0            1        0           1        0.711111
# 2              0            1        0           1        0.711111
# 3              0            1        0           1        0.711111
# 4              0            1        1           0        0.444444
# ...          ...          ...      ...         ...             ...
# 21776585       0            1        2           1        0.444444
# 21776586       0            1        2           1        0.333333
# 21776587       0            1        3           1        0.444444
# 21776588       0            1        3           1        0.444444
# 21776589       0            1        3           1        0.444444
#
#           baggage_pieces flight_number purchace_date departure_date  \
# 0                      0           c-2    2020-12-31     2021-01-10
# ...

# %%
df[['purchase','n']]=df['purchace_time'].str.split('.', expand=True)
df.drop('n', inplace=True, axis=1)
df.drop('purchace_time', inplace=True, axis=1)

# %%
# Dataset having x and y both values will do train test split later. 
df.to_csv("Train.csv",index=False)

# %%
df1 = df.sample(n=30000)

# %%
df1.to_csv("sample_30000.csv",index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21776590 entries, 0 to 21776589
# Data columns (total 13 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   origin          object
#  1   destination     object
#  2   airline         int64
#  3   refundable      int64
#  4   baggage_weight  float64
#  5   baggage_pieces  int64
#  6   flight_number   object
#  7   purchace_date   object
#  8   departure_date  object
#  9   arival_date     object
#  10  purchace_time   object
#  11  departure_time  object
#  12  arival_time     object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 2.1+ GB

# %%
df=pd.read_csv('Train.csv')

# %%
df.head()
# Out:
#   origin destination  airline  refundable  baggage_weight  baggage_pieces  \
# 0      x           y        0           1        0.000000               0
# 1      x           y        0           1        0.711111               1
# 2      x           y        0           1        0.711111               1
# 3      x           y        0           1        0.711111               2
# 4      x           y        1           0        0.444444               0
#
#   flight_number purchace_date departure_date arival_date  ...  \
# 0           c-2    2020-12-31     2021-01-10  2021-01-10  ...
# 1           c-2    2020-12-31     2021-01-10  2021-01-10  ...
# 2           c-4    2020-12-31     2021-01-10  2021-01-10  ...
# 3           c-4    2020-12-31     2021-01-10  2021-01-10  ...
# 4          b-69    2020-12-31     2021-01-25  2021-01-25  ...
#
#   purchace_date_month purchace_date_day  purchace_date_year  \
# 0                  12                31                2020
# ...

# %%
time_cols = ['purchase','departure_time','arival_time']
date_cols = ['purchace_date','departure_date','arival_date']

for col in date_cols:
    df['{}_month'.format(col)] =  pd.to_datetime(df['{}'.format(col)],format='%Y-%m-%d').dt.month
    df['{}_day'.format(col)] =  pd.to_datetime(df['{}'.format(col)],format='%Y-%m-%d').dt.day
    df['{}_year'.format(col)] =  pd.to_datetime(df['{}'.format(col)],format='%Y-%m-%d').dt.year

for col in time_cols:
    df['{}_hour'.format(col)] =  pd.to_datetime(df['{}'.format(col)],format='%H:%M:%S').dt.hour
    df['{}_minutes'.format(col)] =  pd.to_datetime(df['{}'.format(col)],format='%H:%M:%S').dt.minute

# %%
df.head()
# Out:
#   origin destination  airline  refundable  baggage_weight  baggage_pieces  \
# 0      x           y        0           1        0.000000               0
# 1      x           y        0           1        0.711111               1
# 2      x           y        0           1        0.711111               1
# 3      x           y        0           1        0.711111               2
# 4      x           y        1           0        0.444444               0
#
#   flight_number purchace_date departure_date arival_date  ...  purchase  \
# 0           c-2    2020-12-31     2021-01-10  2021-01-10  ...  09:46:17
# 1           c-2    2020-12-31     2021-01-10  2021-01-10  ...  09:46:17
# 2           c-4    2020-12-31     2021-01-10  2021-01-10  ...  09:46:17
# 3           c-4    2020-12-31     2021-01-10  2021-01-10  ...  09:46:17
# 4          b-69    2020-12-31     2021-01-25  2021-01-25  ...  09:46:18
#
#   purchase_hour  purchase_minutes  purchase_seconds  departure_time_hour  \
# ...

# %%
df['purchace_date'] = pd.to_datetime(df['purchace_date'])

# %%
df['departure_date'] = pd.to_datetime(df['departure_date'])

# %%
df['arival_date'] = pd.to_datetime(df['arival_date'])

# %%
df['purchace_time'] = pd.to_datetime(df['purchace_time'])

# %%
df['departure_time'] = pd.to_datetime(df['departure_time'])

# %%
df['arival_time'] = pd.to_datetime(df['arival_time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21776590 entries, 0 to 21776589
# Data columns (total 14 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   origin          int64
#  1   destination     int64
#  2   airline         int64
#  3   refundable      int64
#  4   baggage_weight  float64
#  5   baggage_pieces  int64
#  6   flight_number   object
#  7   purchace_date   datetime64[ns]
#  8   departure_date  datetime64[ns]
#  9   arival_date     datetime64[ns]
#  10  purchace_time   datetime64[ns]
#  11  departure_time  datetime64[ns]
#  12  arival_time     datetime64[ns]
#  13  price           float64
# dtypes: datetime64[ns](6), float64(2), int64(5), object(1)
# memory usage: 2.3+ GB

# %%
df1 = df.sample(n=30000)

# %%
df1.head()
# Out:
#           origin  destination  airline  refundable  baggage_weight  \
# 11159720       0            1        2           1        0.333333
# 2448161        0            1        0           1        0.444444
# 16477672       0            1        2           1        0.777778
# 7194938        0            1        2           1        0.333333
# 20729948       0            1        3           1        0.444444
#
#           baggage_pieces flight_number purchace_date departure_date  \
# 11159720               1           a-7    2021-06-25     2021-06-28
# 2448161                2           c-4    2021-03-02     2021-03-08
# 16477672               1          a-23    2021-07-30     2021-08-06
# 7194938                1           a-1    2021-05-19     2021-05-20
# 20729948               1           d-3    2021-08-24     2021-09-19
#
#          arival_date    purchace_time departure_time arival_time    price
# 11159720  2021-06-28  05:49:40.818724       10:30:00    12:30:00   7900.0
# ...

# %%
df = pd.read_csv('Train.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  origin  destination  airline  refundable  baggage_weight  \
# 0           0       0            1        0           1        0.000000
# 1           1       0            1        0           1        0.711111
# 2           2       0            1        0           1        0.711111
# 3           3       0            1        0           1        0.711111
# 4           4       0            1        1           0        0.444444
#
#    baggage_pieces flight_number purchace_date departure_date arival_date  \
# 0               0           c-2    2020-12-31     2020-12-31  2020-12-31
# 1               1           c-2    2020-12-31     2020-12-31  2020-12-31
# 2               1           c-4    2020-12-31     2020-12-31  2020-12-31
# 3               2           c-4    2020-12-31     2020-12-31  2020-12-31
# 4               0          b-69    2020-12-31     2020-12-31  2020-12-31
#
#                 purchace_time       departure_time          arival_time  \
# ...

# %%
df['origin'] = df['origin'].replace(0,'x')
df['destination'] = df['destination'].replace(1,'y')

# %%
df['destination'] = df['destination'].replace(1,'y')

# %%
df = df.drop("Unnamed: 0",axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0 origin destination  airline  refundable  baggage_weight  \
# 0           0      x           y        0           1        0.000000
# 1           1      x           y        0           1        0.711111
# 2           2      x           y        0           1        0.711111
# 3           3      x           y        0           1        0.711111
# 4           4      x           y        1           0        0.444444
#
#    baggage_pieces flight_number purchace_date departure_date arival_date  \
# 0               0           c-2    2020-12-31     2020-12-31  2020-12-31
# 1               1           c-2    2020-12-31     2020-12-31  2020-12-31
# 2               1           c-4    2020-12-31     2020-12-31  2020-12-31
# 3               2           c-4    2020-12-31     2020-12-31  2020-12-31
# 4               0          b-69    2020-12-31     2020-12-31  2020-12-31
#
#                 purchace_time       departure_time          arival_time  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21776590 entries, 0 to 21776589
# Data columns (total 14 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   origin          int64
#  1   destination     int64
#  2   airline         int64
#  3   refundable      int64
#  4   baggage_weight  float64
#  5   baggage_pieces  int64
#  6   flight_number   object
#  7   purchace_date   datetime64[ns]
#  8   departure_date  datetime64[ns]
#  9   arival_date     datetime64[ns]
#  10  purchace_time   datetime64[ns]
#  11  departure_time  datetime64[ns]
#  12  arival_time     datetime64[ns]
#  13  price           float64
# dtypes: datetime64[ns](6), float64(2), int64(5), object(1)
# memory usage: 2.3+ GB

# %%
plt.figure(figsize=(25,8))
plt.title('Correlation Matrix\n')
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df = pd.read_csv('X_train.csv')

# %%
plt.figure(figsize=(25,8))
plt.title('Correlation Matrix\n')
sns.heatmap(df.corr(),annot=True)
plt.show()
