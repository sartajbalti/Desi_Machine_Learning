# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('covid.csv')
df = df.sample(300)

# %%
df.head()
# Out:
#        iso_code continent        location        date  total_cases  new_cases  \
# 165882      GBR    Europe  United Kingdom  2020-02-22         23.0        0.0
# 3790        AND    Europe         Andorra  2022-01-20      32201.0     2313.0
# 89381       LBN      Asia         Lebanon  2021-09-03     605521.0     1112.0
# 166250      GBR    Europe  United Kingdom  2021-02-24    4148605.0     9938.0
# 10280       AUT    Europe         Austria  2020-08-29      26985.0      395.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 165882               0.714           NaN         NaN                  NaN
# 3790               471.714         144.0         2.0                0.429
# 89381             1077.571        8079.0         9.0                6.286
# 166250           10487.714      121832.0       442.0              402.000
# 10280              274.714         733.0         0.0                0.143
#
# ...

# %%
df.isnull().sum()
# Out:
# iso_code                                     0
# continent                                   20
# location                                     0
# date                                         0
# total_cases                                 14
#                                           ...
# human_development_index                     61
# excess_mortality_cumulative_absolute       293
# excess_mortality_cumulative                293
# excess_mortality                           293
# excess_mortality_cumulative_per_million    293
# Length: 67, dtype: int64

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
df.drop(df.iloc[:, 10:], inplace = True, axis = 1)

# %%
df.head()
# Out:
#        iso_code continent        location        date  total_cases  new_cases  \
# 165882      GBR    Europe  United Kingdom  2020-02-22         23.0        0.0
# 3790        AND    Europe         Andorra  2022-01-20      32201.0     2313.0
# 89381       LBN      Asia         Lebanon  2021-09-03     605521.0     1112.0
# 166250      GBR    Europe  United Kingdom  2021-02-24    4148605.0     9938.0
# 10280       AUT    Europe         Austria  2020-08-29      26985.0      395.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed
# 165882               0.714           NaN         NaN                  NaN
# 3790               471.714         144.0         2.0                0.429
# 89381             1077.571        8079.0         9.0                6.286
# 166250           10487.714      121832.0       442.0              402.000
# 10280              274.714         733.0         0.0                0.143

# %%
df.isnull().sum()
# Out:
# iso_code                0
# continent              20
# location                0
# date                    0
# total_cases            14
# new_cases              14
# new_cases_smoothed     18
# total_deaths           42
# new_deaths             42
# new_deaths_smoothed    44
# dtype: int64

# %%
df1 = df.dropna()

# %%
df1.isnull().sum()
# Out:
# iso_code               0
# continent              0
# location               0
# date                   0
# total_cases            0
# new_cases              0
# new_cases_smoothed     0
# total_deaths           0
# new_deaths             0
# new_deaths_smoothed    0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 235 entries, 3790 to 98118
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   iso_code             235 non-null    object
#  1   continent            235 non-null    object
#  2   location             235 non-null    object
#  3   date                 235 non-null    object
#  4   total_cases          235 non-null    float64
#  5   new_cases            235 non-null    float64
#  6   new_cases_smoothed   235 non-null    float64
#  7   total_deaths         235 non-null    float64
#  8   new_deaths           235 non-null    float64
#  9   new_deaths_smoothed  235 non-null    float64
# dtypes: float64(6), object(4)
# memory usage: 20.2+ KB

# %%
df['new_deaths'].

# %%
df1.head()
# Out:
#        iso_code continent        location        date  total_cases  new_cases  \
# 3790        AND    Europe         Andorra  2022-01-20      32201.0     2313.0
# 89381       LBN      Asia         Lebanon  2021-09-03     605521.0     1112.0
# 166250      GBR    Europe  United Kingdom  2021-02-24    4148605.0     9938.0
# 10280       AUT    Europe         Austria  2020-08-29      26985.0      395.0
# 3308        AND    Europe         Andorra  2020-09-25       1836.0       83.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed
# 3790               471.714         144.0         2.0                0.429
# 89381             1077.571        8079.0         9.0                6.286
# 166250           10487.714      121832.0       442.0              402.000
# 10280              274.714         733.0         0.0                0.143
# 3308                38.857          53.0         0.0                0.000

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed'],
#       dtype='object')

# %%
df1['new_deaths'].isnull().sum()
# Out:
# 0

# %%
df1.to_csv('newdata.csv', index=False)

# %%
#df.tail()
# Out:
#           Unnamed: 0                                f1 f2 f3  \
# 21776585    21776585  2021-08-31 23:29:18.122593+00:00  x  y
# 21776586    21776586  2021-08-31 23:29:18.122593+00:00  x  y
# 21776587    21776587  2021-08-31 23:29:18.961691+00:00  x  y
# 21776588    21776588  2021-08-31 23:29:18.961691+00:00  x  y
# 21776589    21776589  2021-08-31 23:29:18.961691+00:00  x  y
#
#                                  f4                         f5     f6    f7  \
# 21776585  2021-09-03 10:00:00+00:00  2021-09-03 12:00:00+00:00  alpha  True
# 21776586  2021-09-03 13:40:00+00:00  2021-09-03 15:40:00+00:00  alpha  True
# 21776587  2021-09-03 04:40:00+00:00  2021-09-03 06:40:00+00:00  omega  True
# 21776588  2021-09-03 10:35:00+00:00  2021-09-03 12:35:00+00:00  omega  True
# 21776589  2021-09-03 17:05:00+00:00  2021-09-03 19:05:00+00:00  omega  True
#
#             f8  f9  f10
# 21776585  20.0   1  a-7
# 21776586  15.0   1  a-9
# 21776587  20.0   1  d-1
# 21776588  20.0   1  d-3
# ...

# %%
#df.isna().sum()
# Out:
# Unnamed: 0    0
# f1            0
# f2            0
# f3            0
# f4            0
# f5            0
# f6            0
# f7            0
# f8            0
# f9            0
# f10           0
# dtype: int64

# %% [markdown]
# ### ***Dataset X includes the following features:***
#
# - f1: Ticket Purchase Date Time
# - f2: Origin
# - f3: Destination
# - f4: Departure Date Time
# - f5: Arrival Date Time
# - f6: Airline
# - f7: Refundable Ticket
# - f8: Baggage Weight
# - f9: Baggage Pieces
# - f10: Flight Number

# %%
# Changing the string into number we consider origin as 0 and Destination as 1
df = df.replace('x',0)

# %%
# Changing the string into number we consider origin as 0 and Destination as 1
df = df.replace('y',1)

# %%
#df.head()
# Out:
#    Unnamed: 0                                f1  f2  f3  \
# 0           0  2020-12-31 09:46:17.463002+00:00   0   1
# 1           1  2020-12-31 09:46:17.463002+00:00   0   1
# 2           2  2020-12-31 09:46:17.463002+00:00   0   1
# 3           3  2020-12-31 09:46:17.463002+00:00   0   1
# 4           4  2020-12-31 09:46:18.191119+00:00   0   1
#
#                           f4                         f5     f6     f7    f8  \
# 0  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00  gamma   True   0.0
# 1  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00  gamma   True  32.0
# 2  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00  gamma   True  32.0
# 3  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00  gamma   True  32.0
# 4  2021-01-25 11:00:00+00:00  2021-01-25 12:55:00+00:00   beta  False  20.0
#
#    f9   f10
# 0   0   c-2
# 1   1   c-2
# 2   1   c-4
# 3   2   c-4
# 4   0  b-69

# %%
# mean max method on f8 baggage weight to normalize the data
df['f8'] = (df['f8']-df['f8'].min())/(df['f8'].max()-df['f8'].min())

# %%
#df.head()
# Out:
#    Unnamed: 0                                f1  f2  f3  \
# 0           0  2020-12-31 09:46:17.463002+00:00   0   1
# 1           1  2020-12-31 09:46:17.463002+00:00   0   1
# 2           2  2020-12-31 09:46:17.463002+00:00   0   1
# 3           3  2020-12-31 09:46:17.463002+00:00   0   1
# 4           4  2020-12-31 09:46:18.191119+00:00   0   1
#
#                           f4                         f5     f6     f7  \
# 0  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00  gamma   True
# 1  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00  gamma   True
# 2  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00  gamma   True
# 3  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00  gamma   True
# 4  2021-01-25 11:00:00+00:00  2021-01-25 12:55:00+00:00   beta  False
#
#          f8  f9   f10
# 0  0.000000   0   c-2
# 1  0.711111   1   c-2
# 2  0.711111   1   c-4
# 3  0.711111   2   c-4
# 4  0.444444   0  b-69

# %%
#Replacing the Booleans to 1/0
df["f7"] = df["f7"].astype(int)

# %%
#df.head()
# Out:
#    Unnamed: 0                                f1  f2  f3  \
# 0           0  2020-12-31 09:46:17.463002+00:00   0   1
# 1           1  2020-12-31 09:46:17.463002+00:00   0   1
# 2           2  2020-12-31 09:46:17.463002+00:00   0   1
# 3           3  2020-12-31 09:46:17.463002+00:00   0   1
# 4           4  2020-12-31 09:46:18.191119+00:00   0   1
#
#                           f4                         f5     f6  f7        f8  \
# 0  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00  gamma   1  0.000000
# 1  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00  gamma   1  0.711111
# 2  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00  gamma   1  0.711111
# 3  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00  gamma   1  0.711111
# 4  2021-01-25 11:00:00+00:00  2021-01-25 12:55:00+00:00   beta   0  0.444444
#
#    f9   f10
# 0   0   c-2
# 1   1   c-2
# 2   1   c-4
# 3   2   c-4
# 4   0  b-69

# %%
#df.tail()
# Out:
#           Unnamed: 0                                f1  f2  f3  \
# 21776585    21776585  2021-08-31 23:29:18.122593+00:00   0   1
# 21776586    21776586  2021-08-31 23:29:18.122593+00:00   0   1
# 21776587    21776587  2021-08-31 23:29:18.961691+00:00   0   1
# 21776588    21776588  2021-08-31 23:29:18.961691+00:00   0   1
# 21776589    21776589  2021-08-31 23:29:18.961691+00:00   0   1
#
#                                  f4                         f5     f6  f7  \
# 21776585  2021-09-03 10:00:00+00:00  2021-09-03 12:00:00+00:00  alpha   1
# 21776586  2021-09-03 13:40:00+00:00  2021-09-03 15:40:00+00:00  alpha   1
# 21776587  2021-09-03 04:40:00+00:00  2021-09-03 06:40:00+00:00  omega   1
# 21776588  2021-09-03 10:35:00+00:00  2021-09-03 12:35:00+00:00  omega   1
# 21776589  2021-09-03 17:05:00+00:00  2021-09-03 19:05:00+00:00  omega   1
#
#                 f8  f9  f10
# 21776585  0.444444   1  a-7
# 21776586  0.333333   1  a-9
# 21776587  0.444444   1  d-1
# ...

# %%
df1 = pd.read_csv('y_train.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0   target
# 0           0   7400.0
# 1           1   8650.0
# 2           2   9150.0
# 3           3  10400.0
# 4           4   8697.0

# %%
df1.tail()
# Out:
#           Unnamed: 0  target
# 21776585    21776585  8381.0
# 21776586    21776586  9045.0
# 21776587    21776587  6155.0
# 21776588    21776588  6155.0
# 21776589    21776589  6605.0

# %%
#df.describe()
# Out:
#          Unnamed: 0          f2          f3            f7            f8  \
# count  2.177659e+07  21776590.0  21776590.0  2.177659e+07  2.177659e+07
# mean   1.088829e+07         0.0         1.0  9.936872e-01  5.019902e-01
# std    6.286360e+06         0.0         0.0  7.920188e-02  1.974526e-01
# min    0.000000e+00         0.0         1.0  0.000000e+00  0.000000e+00
# 25%    5.444147e+06         0.0         1.0  1.000000e+00  4.444444e-01
# 50%    1.088829e+07         0.0         1.0  1.000000e+00  4.444444e-01
# 75%    1.633244e+07         0.0         1.0  1.000000e+00  7.111111e-01
# max    2.177659e+07         0.0         1.0  1.000000e+00  1.000000e+00
#
#                  f9
# count  2.177659e+07
# mean   9.491727e-01
# std    6.077294e-01
# min    0.000000e+00
# 25%    1.000000e+00
# 50%    1.000000e+00
# 75%    1.000000e+00
# max    2.000000e+00

# %%
#df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21776590 entries, 0 to 21776589
# Data columns (total 11 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Unnamed: 0  int64
#  1   f1          object
#  2   f2          int64
#  3   f3          int64
#  4   f4          object
#  5   f5          object
#  6   f6          object
#  7   f7          int32
#  8   f8          float64
#  9   f9          int64
#  10  f10         object
# dtypes: float64(1), int32(1), int64(4), object(5)
# memory usage: 1.7+ GB

# %%
#df.duplicated().sum()
# Out:
# 0

# %%
df[['pd','pt']]=df['f1'].str.split(' ', expand=True)

# %%
df.head()
# Out:
#    Unnamed: 0                                f1  f2  f3  \
# 0           0  2020-12-31 09:46:17.463002+00:00   0   1
# 1           1  2020-12-31 09:46:17.463002+00:00   0   1
# 2           2  2020-12-31 09:46:17.463002+00:00   0   1
# 3           3  2020-12-31 09:46:17.463002+00:00   0   1
# 4           4  2020-12-31 09:46:18.191119+00:00   0   1
#
#                           f4                         f5     f6  f7        f8  \
# 0  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00  gamma   1  0.000000
# 1  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00  gamma   1  0.711111
# 2  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00  gamma   1  0.711111
# 3  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00  gamma   1  0.711111
# 4  2021-01-25 11:00:00+00:00  2021-01-25 12:55:00+00:00   beta   0  0.444444
#
#    f9   f10          pd                     pt
# 0   0   c-2  2020-12-31  09:46:17.463002+00:00
# 1   1   c-2  2020-12-31  09:46:17.463002+00:00
# ...

# %%
df[['dd','dt']]=df['f4'].str.split(' ', expand=True)

# %%
df[['ad','at']]=df['f5'].str.split(' ', expand=True)

# %%
df.head()
# Out:
#    Unnamed: 0                                f1  f2  f3  \
# 0           0  2020-12-31 09:46:17.463002+00:00   0   1
# 1           1  2020-12-31 09:46:17.463002+00:00   0   1
# 2           2  2020-12-31 09:46:17.463002+00:00   0   1
# 3           3  2020-12-31 09:46:17.463002+00:00   0   1
# 4           4  2020-12-31 09:46:18.191119+00:00   0   1
#
#                           f4                         f5     f6  f7        f8  \
# 0  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00  gamma   1  0.000000
# 1  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00  gamma   1  0.711111
# 2  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00  gamma   1  0.711111
# 3  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00  gamma   1  0.711111
# 4  2021-01-25 11:00:00+00:00  2021-01-25 12:55:00+00:00   beta   0  0.444444
#
#    f9   f10          pd                     pt          dd              dt  \
# 0   0   c-2  2020-12-31  09:46:17.463002+00:00  2021-01-10  05:00:00+00:00
# ...

# %%
df.drop('f1', inplace=True, axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0  f2  f3                         f4                         f5  \
# 0           0   0   1  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00
# 1           1   0   1  2021-01-10 05:00:00+00:00  2021-01-10 07:00:00+00:00
# 2           2   0   1  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00
# 3           3   0   1  2021-01-10 11:00:00+00:00  2021-01-10 13:00:00+00:00
# 4           4   0   1  2021-01-25 11:00:00+00:00  2021-01-25 12:55:00+00:00
#
#       f6  f7        f8  f9   f10          pd                     pt  \
# 0  gamma   1  0.000000   0   c-2  2020-12-31  09:46:17.463002+00:00
# 1  gamma   1  0.711111   1   c-2  2020-12-31  09:46:17.463002+00:00
# 2  gamma   1  0.711111   1   c-4  2020-12-31  09:46:17.463002+00:00
# 3  gamma   1  0.711111   2   c-4  2020-12-31  09:46:17.463002+00:00
# 4   beta   0  0.444444   0  b-69  2020-12-31  09:46:18.191119+00:00
#
#            dd              dt          ad              at
# ...

# %%
df.drop('f4', inplace=True, axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0  f2  f3                         f5     f6  f7        f8  f9  \
# 0           0   0   1  2021-01-10 07:00:00+00:00  gamma   1  0.000000   0
# 1           1   0   1  2021-01-10 07:00:00+00:00  gamma   1  0.711111   1
# 2           2   0   1  2021-01-10 13:00:00+00:00  gamma   1  0.711111   1
# 3           3   0   1  2021-01-10 13:00:00+00:00  gamma   1  0.711111   2
# 4           4   0   1  2021-01-25 12:55:00+00:00   beta   0  0.444444   0
#
#     f10          pd                     pt          dd              dt  \
# 0   c-2  2020-12-31  09:46:17.463002+00:00  2021-01-10  05:00:00+00:00
# 1   c-2  2020-12-31  09:46:17.463002+00:00  2021-01-10  05:00:00+00:00
# 2   c-4  2020-12-31  09:46:17.463002+00:00  2021-01-10  11:00:00+00:00
# 3   c-4  2020-12-31  09:46:17.463002+00:00  2021-01-10  11:00:00+00:00
# 4  b-69  2020-12-31  09:46:18.191119+00:00  2021-01-25  11:00:00+00:00
#
#            ad              at
# 0  2021-01-10  07:00:00+00:00
# 1  2021-01-10  07:00:00+00:00
# ...

# %%
df.drop('f5', inplace=True, axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0  f2  f3     f6  f7        f8  f9   f10          pd  \
# 0           0   0   1  gamma   1  0.000000   0   c-2  2020-12-31
# 1           1   0   1  gamma   1  0.711111   1   c-2  2020-12-31
# 2           2   0   1  gamma   1  0.711111   1   c-4  2020-12-31
# 3           3   0   1  gamma   1  0.711111   2   c-4  2020-12-31
# 4           4   0   1   beta   0  0.444444   0  b-69  2020-12-31
#
#                       pt          dd              dt          ad  \
# 0  09:46:17.463002+00:00  2021-01-10  05:00:00+00:00  2021-01-10
# 1  09:46:17.463002+00:00  2021-01-10  05:00:00+00:00  2021-01-10
# 2  09:46:17.463002+00:00  2021-01-10  11:00:00+00:00  2021-01-10
# 3  09:46:17.463002+00:00  2021-01-10  11:00:00+00:00  2021-01-10
# 4  09:46:18.191119+00:00  2021-01-25  11:00:00+00:00  2021-01-25
#
#                at
# 0  07:00:00+00:00
# 1  07:00:00+00:00
# 2  13:00:00+00:00
# 3  13:00:00+00:00
# 4  12:55:00+00:00

# %%
df.to_csv("train.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21776590 entries, 0 to 21776589
# Data columns (total 14 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Unnamed: 0  int64
#  1   f2          int64
#  2   f3          int64
#  3   f6          object
#  4   f7          int32
#  5   f8          float64
#  6   f9          int64
#  7   f10         object
#  8   pd          object
#  9   pt          object
#  10  dd          object
#  11  dt          object
#  12  ad          object
#  13  at          object
# dtypes: float64(1), int32(1), int64(4), object(8)
# memory usage: 2.2+ GB

# %%
#df.rename(columns={"f2": "origin", "f3": "destination"})
# Out:
#           Unnamed: 0  origin  destination     f6  f7        f8  f9   f10  \
# 0                  0       0            1  gamma   1  0.000000   0   c-2
# 1                  1       0            1  gamma   1  0.711111   1   c-2
# 2                  2       0            1  gamma   1  0.711111   1   c-4
# 3                  3       0            1  gamma   1  0.711111   2   c-4
# 4                  4       0            1   beta   0  0.444444   0  b-69
# ...              ...     ...          ...    ...  ..       ...  ..   ...
# 21776585    21776585       0            1  alpha   1  0.444444   1   a-7
# 21776586    21776586       0            1  alpha   1  0.333333   1   a-9
# 21776587    21776587       0            1  omega   1  0.444444   1   d-1
# 21776588    21776588       0            1  omega   1  0.444444   1   d-3
# 21776589    21776589       0            1  omega   1  0.444444   1   d-5
#
#                   pd                     pt          dd              dt  \
# ...

# %%
#df.rename(columns={"f2": "origin", "f3": "destination","f6": "airline", "f7": "refundable","f8": "baggage_weight", "f9": "baggage_pieces","f10":"flight_number"})
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24032/1291420811.py in <module>
# ----> 1 df.rename(columns={"f2": "origin", "f3": "destination","f6": "airline", "f7": "refundable","f8": "baggage_weight", "f9": "baggage_pieces","f10":"flight_number"})
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     322         @wraps(func)
#     323         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324             return func(*args, **kwargs)
#     325
#     326         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5037         4  3  6
#    5038         """
# -> 5039         return super().rename(
#    5040             mapper=mapper,
# ...

# %%
#df[['purchace_time','n']]=df['pt'].str.split('+', expand=True)

# %%
#df.head()
# Out:
#    Unnamed: 0  f2  f3     f6  f7        f8  f9   f10          pd  \
# 0           0   0   1  gamma   1  0.000000   0   c-2  2020-12-31
# 1           1   0   1  gamma   1  0.711111   1   c-2  2020-12-31
# 2           2   0   1  gamma   1  0.711111   1   c-4  2020-12-31
# 3           3   0   1  gamma   1  0.711111   2   c-4  2020-12-31
# 4           4   0   1   beta   0  0.444444   0  b-69  2020-12-31
#
#                       pt          dd              dt          ad  \
# 0  09:46:17.463002+00:00  2021-01-10  05:00:00+00:00  2021-01-10
# 1  09:46:17.463002+00:00  2021-01-10  05:00:00+00:00  2021-01-10
# 2  09:46:17.463002+00:00  2021-01-10  11:00:00+00:00  2021-01-10
# 3  09:46:17.463002+00:00  2021-01-10  11:00:00+00:00  2021-01-10
# 4  09:46:18.191119+00:00  2021-01-25  11:00:00+00:00  2021-01-25
#
#                at    purchace_time      n
# 0  07:00:00+00:00  09:46:17.463002  00:00
# 1  07:00:00+00:00  09:46:17.463002  00:00
# 2  13:00:00+00:00  09:46:17.463002  00:00
# ...
